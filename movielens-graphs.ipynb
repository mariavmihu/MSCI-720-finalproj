# %%
# General libraries
import csv
import json
import math
import numpy as np
import os
from os.path import isfile, join
import pandas as pd
from pathlib import Path as Data_Path
import pickle
import random

import matplotlib.pyplot as plt
# %matplotlib inline

import networkx as nx
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import Tensor
from torch.nn import Embedding, Linear, ModuleList
from typing import Optional, Union

from tqdm.notebook import tqdm

# PyTorch Geometric
import torch_geometric
import torch_geometric.nn as pyg_nn
from torch_geometric.data import Data
from torch_geometric.transforms import RandomLinkSplit
from torch_geometric.utils import negative_sampling, to_networkx
from torch_geometric.nn.conv import LGConv
from torch_geometric.typing import Adj, OptTensor, SparseTensor

# %% [markdown]
# #### Read Dataset

# %%
RATINGS_CSV = "./data/full-dataset/ml-explicit/ratings.csv"
MOVIES_CSV = "./data/full-dataset/ml-explicit/movies.csv"
ratings_df = pd.read_csv("./data/full-dataset/ml-explicit/ratings.csv")
movies_df = pd.read_csv("./data/full-dataset/ml-explicit/movies.csv")

# %%
# Merge the dataframes on 'movieId' column
full_ratings_df = pd.merge(ratings_df, movies_df[['movieId', 'title']], on='movieId', how='left')
# Rename the columns
full_ratings_df = full_ratings_df.rename(columns={'title': 'movieName'})
# Reorder the columns --> this is going to let me get movie information later
full_ratings_df = full_ratings_df[['userId', 'movieId', 'movieName', 'rating', 'timestamp']]

# %%
full_ratings_df.head(5)
# Out:
#    userId  movieId                    movieName  rating  timestamp
# 0       1       17       Sense and Sensibility      4.0  944249077
# 1       1       25           Leaving Las Vegas      1.0  944250228
# 2       1       29  City of Lost Children, The      2.0  943230976
# 3       1       30              Shanghai Triad      5.0  944249077
# 4       1       32              Twelve Monkeys      5.0  943228858

# %% [markdown]
# #### Graph Construction

# %%
""" 
  Defining classes to use in the graph. 
  Attempting to build a bipartite graph where the two node types are users and movies. 
"""

movies = []

class Movie:
  """
  Class for a movie, which contains:
    1. ID (unique to Movielens dataset)
    2. Name (the name of the movie)
  """

  def __init__(self, movielens_id):
    self.movielens_id = int(movielens_id)
    self.name = f"movie_{self.movielens_id}"
    self.title = str(IDS_TO_MOVIES[movielens_id])

  def __str__(self):
    return f"Movie {self.movielens_id}: {self.title}"

  def __repr__(self):
    return self.name

# %%
class User:
  """
  Class for a user, which contains:
    1. ID (user id on the movielens platform)
    2. Ratings (dictionary of movies rated and their ratings)
  """

  def __init__(self, user_id, ratings):
    self.id = int(user_id)
    self.name = f"user_{user_id}"
    self.ratings = {f"movie_{key}": value/5 for key,value in ratings.items()}

  def __str__(self):
    return f"User: {self.name}"

  def __repr__(self):
    return f"{self.name}"

# %%
users = []

grouped_df = full_ratings_df.groupby('userId')

# this is basically allowing me to control how many users I am constructing the graph for.
count = 0

for userID, group_df in grouped_df:
    if count >= 20000 and userID != 200952: #getting the first 10,000 users plus my user
        continue
    elif userID%10 != 0 and userID != 200952:
        continue
    # if userID <= 178745: #getting the last 20,000 users plus my user
    #     continue
    ratings_dict = dict(zip(group_df['movieId'], group_df['rating']))
    user = User(userID, ratings_dict)
    users.append(user)
    count += 1

# we have a list of users, now we just need a list of all the unique movies
movies = [Movie(x) for x in IDS_TO_MOVIES.keys()] 

print(len(users), len(movies))
# Out:
# 20001 31271

# %%
import networkx as nx

MovielensGraph = nx.Graph()
MovielensGraph.add_nodes_from([
    (u.name, {'name':u.name, "node_type" : "user"}) for u in users
])
MovielensGraph.add_nodes_from([
    (m.name, {'name':m.name, "node_type" : "movies"}) for m in movies
])

edge_list = []
for user in users:
  for movie in user.ratings.keys():
    edge_list.append((user.name, movie))
MovielensGraph.add_edges_from(edge_list)

print('Num nodes:', MovielensGraph.number_of_nodes(), '. Num edges:', MovielensGraph.number_of_edges())
# Out:
# Num nodes: 51272 . Num edges: 3128042

# %%
# reduce the graph into a smaller subgraph for handling directly on the PC
kcore = 30
MovielensGraph = nx.k_core(MovielensGraph, kcore)
print('Num nodes:', MovielensGraph.number_of_nodes(), '. Num edges:', MovielensGraph.number_of_edges())
# Out:
# Num nodes: 24166 . Num edges: 2916980

# %%
if "user_200952" in nx.get_node_attributes(MovielensGraph, 'name').keys():
    print("Maria user detected") # making sure that my user is in the graph
# Out:
# Maria user detected

# %%
n_nodes, n_edges = MovielensGraph.number_of_nodes(), MovielensGraph.number_of_edges()

sorted_nodes = sorted(list(MovielensGraph.nodes()))
# these will be useful when accessing nodes and recommendations later
node2id = dict(zip(sorted_nodes, np.arange(n_nodes)))
id2node = dict(zip(np.arange(n_nodes), sorted_nodes))

# nodes need integer IDs for training with torch_geometric
MovielensGraph = nx.relabel_nodes(MovielensGraph, node2id)

# %%
if "user_200952" in nx.get_node_attributes(MovielensGraph, 'name').values():
    print("Maria user detected") # double-checking again just to make sure
# Out:
# Maria user detected

# %%
# keep track of how many users / movies we have and make the lists torch-compatible
users_idx = [i for i, v in enumerate(node2id.keys()) if "user" in v]
movies_idx = [i for i, v in enumerate(node2id.keys()) if "movie" in v]

n_users = len(users_idx)
n_movies = len(movies_idx)

users_idx = torch.Tensor(users_idx).type(torch.int64)
movies_idx =torch.Tensor(movies_idx).type(torch.int64)

n_users, n_movies
# Out:
# (16500, 7666)

# %%
num_nodes = n_users +  n_movies
edge_idx = torch.Tensor(np.array(MovielensGraph.edges()).T).type(torch.int64)
graph_data = Data(edge_index = edge_idx, num_nodes = num_nodes)

# convert to train/val/test splits
transform = RandomLinkSplit(
    is_undirected=True,
    add_negative_train_samples=False,
    neg_sampling_ratio=0,
    num_val=0.15,
    num_test=0.15
)
train_split, val_split, test_split = transform(graph_data)

# %% [markdown]
# #### Building the GNN Model

# %%
class RecommendationGCN(torch.nn.Module):
    def __init__(
        self,
        num_nodes: int,
        embedding_dim: int,
        num_layers: int,
        conv_layer = "LGC",
        name = None,
    ):
        super().__init__()
        # define hyperparameters
        self.num_nodes = num_nodes
        self.embedding_dim = embedding_dim
        self.num_layers = num_layers
        self.embedding = Embedding(num_nodes, embedding_dim)

        self.alpha = 1. / (num_layers + 1) #this is the multiplicative factor that is used for summing layer embeddings

        # define layers (number of them will depend on hyperparameters)
        self.conv_layers = ModuleList (
            [ LGConv() for _ in range(num_layers) ]
        )
        torch.nn.init.xavier_uniform_(self.embedding.weight)
        for layer in self.conv_layers:
            layer.reset_parameters()


    def get_embedding(self, edge_index: Adj) -> Tensor:
        x = self.embedding.weight
        out = x 

        for i in range(self.num_layers):
            x = self.conv_layers[i](x, edge_index)
            out = out + (x * self.alpha)

        return out


    def get_pred_only(self, embed: Adj, edge_label_index: Adj) -> Tensor:

        user_embeddings = embed[edge_label_index[0]]
        movie_embeddings = embed[edge_label_index[1]]
        return (user_embeddings * movie_embeddings).sum(dim=-1)
    

    # I liked the idea that the authors had to make this part of the model class
    # in order to access the embedding weights more easily.
    def recommendation_loss(
        self,
        loss_fn,
        pos_edge_rank: Tensor,
        neg_edge_rank: Tensor,
    ) -> Tensor:
        return loss_fn(pos_edge_rank, neg_edge_rank, self.embedding.weight)

# %%
# BPRLoss NOTE this method was taken directly from https://medium.com/stanford-cs224w/spotify-track-neural-recommender-system-51d266e31e16 
class BPRLoss(_Loss):
    __constants__ = ['lambda_reg']
    lambda_reg: float

    def __init__(self, lambda_reg: float = 0):
        super().__init__(None, None, "sum")
        self.lambda_reg = lambda_reg

    def forward(
        self,
        positives: Tensor,
        negatives: Tensor,
        parameters: Tensor = None
    ) -> Tensor:

        n_pairs = positives.size(0)
        log_prob = F.logsigmoid(positives - negatives).sum()
        regularization = 0

        if self.lambda_reg != 0:
            regularization = self.lambda_reg * parameters.norm(p=2).pow(2)

        return (-log_prob + regularization) / n_pairs

# %%
# Train
def train(train_data, val_data, model, optimizer, args, name=""):
  stats = {
      'train': {
        'loss': [],
      },
      'val': {
        'loss': [],
      }
  }
  for epoch in range(args["epochs"]):
    model.train()
    optimizer.zero_grad()

    # STEP ONE: perform negative sampling
    neg_edge_index = negative_sampling(train_data.edge_label_index, num_nodes=(n_users, n_movies))
    neg_edge_label = torch.zeros(neg_edge_index.shape[1])

    # STEP TW0: get model embedding
    embed = model.get_embedding(train_data.edge_index)
    
    # STEP THREE: get predictions for positive and negative edges 
    # using the embedding obtained above
    pos_predictions = model.get_pred_only(embed, train_data.edge_label_index)
    neg_predictions = model.get_pred_only(embed, neg_edge_index)

    # STEP FOUR: loss calculations
    # BPRLoss
    lambda_reg = 1e-4  # loss regularization constant
    loss_fn = BPRLoss(lambda_reg)
    loss = model.recommendation_loss(loss_fn, pos_predictions, neg_predictions)

    loss.backward()
    optimizer.step()

    val_loss, val_neg_edge, val_neg_label = test(
        model, val_data, neg_edge_index=None, neg_edge_label=None
    )

    stats['train']['loss'].append(loss)
    stats['val']['loss'].append(val_loss)

    print(f"Epoch {epoch}; Train loss {loss}; Val loss {val_loss}")

  pickle.dump(stats, open(f"model_stats/LightGCN{name}.pkl", "wb"))
  return stats

# %%
# Test
def test(model, val_data, neg_edge_index = None, neg_edge_label = None):

  model.eval()
  with torch.no_grad():
    # STEP ONE: perform negative sampling
    neg_edge_index = negative_sampling(val_data.edge_label_index, num_nodes=(n_users, n_movies))
    neg_edge_label = torch.zeros(neg_edge_index.shape[1])
    # STEP TW0: get model embedding
    embed = model.get_embedding(val_data.edge_index)

    # STEP THREE: get predictions for positive and negative edges 
    # using the embedding obtained above
    pos_predictions = model.get_pred_only(embed, val_data.edge_label_index)
    neg_predictions = model.get_pred_only(embed, neg_edge_index)
    
    # STEP FOUR: loss calculations
    # BPRLoss
    lambda_reg = 1e-4  # loss regularization constant
    loss_fn = BPRLoss(lambda_reg)
    loss = model.recommendation_loss(loss_fn, pos_predictions, neg_predictions)

  return loss, neg_edge_index, neg_edge_label

# %%
# initialize model and and optimizer
hyperparams = {
    'num_layers' :  3,
    'emb_size' : 64,
    'weight_decay': 1e-5,
    'lr': 0.01,
    'epochs': 300
}
model = RecommendationGCN(
    num_nodes = num_nodes,
    num_layers = hyperparams['num_layers'],
    embedding_dim = hyperparams["emb_size"]
)
optimizer = torch.optim.Adam(model.parameters(), lr=hyperparams['lr'], weight_decay=hyperparams['weight_decay'])

# %%
# create directory to save model_stats
if not os.path.exists("model_stats"):
  os.makedirs("model_stats")

train(train_split, val_split, model, optimizer, hyperparams, name="20k-skip10-explicit")
# Out:
# Epoch 0; Train loss 0.6931394934654236; Val loss 0.692793607711792
# Epoch 1; Train loss 0.6927223801612854; Val loss 0.6867653727531433
# Epoch 2; Train loss 0.6866341829299927; Val loss 0.6708593964576721
# Epoch 3; Train loss 0.6705849170684814; Val loss 0.6428906321525574
# Epoch 4; Train loss 0.6423322558403015; Val loss 0.602729856967926
# Epoch 5; Train loss 0.6019803881645203; Val loss 0.5525990128517151
# Epoch 6; Train loss 0.5513163208961487; Val loss 0.49571284651756287
# Epoch 7; Train loss 0.49418994784355164; Val loss 0.43738263845443726
# Epoch 8; Train loss 0.43561244010925293; Val loss 0.38320794701576233
# Epoch 9; Train loss 0.3807418942451477; Val loss 0.33669304847717285
# Epoch 10; Train loss 0.333859384059906; Val loss 0.2998286783695221
# Epoch 11; Train loss 0.2956826984882355; Val loss 0.2738643288612366
# Epoch 12; Train loss 0.26840540766716003; Val loss 0.2549056112766266
# Epoch 13; Train loss 0.24837303161621094; Val loss 0.24114108085632324
# Epoch 14; Train loss 0.23410707712173462; Val loss 0.2324969470500946
# Epoch 15; Train loss 0.2254292368888855; Val loss 0.2272065281867981
# Epoch 16; Train loss 0.2190099060535431; Val loss 0.22159796953201294
# Epoch 17; Train loss 0.215241938829422; Val loss 0.21882593631744385
# Epoch 18; Train loss 0.21156032383441925; Val loss 0.21685023605823517
# Epoch 19; Train loss 0.2087131291627884; Val loss 0.21115392446517944
# Epoch 20; Train loss 0.2059936374425888; Val loss 0.21463297307491302
# Epoch 21; Train loss 0.20324745774269104; Val loss 0.2080632448196411
# Epoch 22; Train loss 0.20155732333660126; Val loss 0.20641085505485535
# Epoch 23; Train loss 0.19792866706848145; Val loss 0.20455969870090485
# Epoch 24; Train loss 0.19770066440105438; Val loss 0.20276014506816864
# Epoch 25; Train loss 0.19594302773475647; Val loss 0.19977006316184998
# Epoch 26; Train loss 0.19407744705677032; Val loss 0.2014659345149994
# Epoch 27; Train loss 0.19151908159255981; Val loss 0.19876757264137268
# Epoch 28; Train loss 0.19193942844867706; Val loss 0.1995532363653183
# Epoch 29; Train loss 0.19059614837169647; Val loss 0.19779658317565918
# Epoch 30; Train loss 0.18967050313949585; Val loss 0.19409123063087463
# Epoch 31; Train loss 0.1888085901737213; Val loss 0.19419047236442566
# Epoch 32; Train loss 0.18862110376358032; Val loss 0.19067484140396118
# Epoch 33; Train loss 0.1875271201133728; Val loss 0.19241395592689514
# Epoch 34; Train loss 0.18744224309921265; Val loss 0.19119364023208618
# Epoch 35; Train loss 0.18806873261928558; Val loss 0.19113825261592865
# Epoch 36; Train loss 0.18661291897296906; Val loss 0.191314697265625
# Epoch 37; Train loss 0.18580687046051025; Val loss 0.1897369921207428
# Epoch 38; Train loss 0.185167133808136; Val loss 0.19054776430130005
# Epoch 39; Train loss 0.18451546132564545; Val loss 0.188072070479393
# Epoch 40; Train loss 0.18299151957035065; Val loss 0.18878090381622314
# Epoch 41; Train loss 0.1825818568468094; Val loss 0.18714554607868195
# Epoch 42; Train loss 0.18058669567108154; Val loss 0.18632036447525024
# Epoch 43; Train loss 0.1793486326932907; Val loss 0.1837085634469986
# Epoch 44; Train loss 0.17799623310565948; Val loss 0.18251647055149078
# Epoch 45; Train loss 0.1765156388282776; Val loss 0.18002335727214813
# Epoch 46; Train loss 0.174882173538208; Val loss 0.17835451662540436
# Epoch 47; Train loss 0.17233963310718536; Val loss 0.17556072771549225
# Epoch 48; Train loss 0.17107756435871124; Val loss 0.17514336109161377
# Epoch 49; Train loss 0.16982914507389069; Val loss 0.1723010390996933
# Epoch 50; Train loss 0.16763663291931152; Val loss 0.17303545773029327
# Epoch 51; Train loss 0.16649039089679718; Val loss 0.171488955616951
# Epoch 52; Train loss 0.1650858074426651; Val loss 0.17019471526145935
# Epoch 53; Train loss 0.1639965921640396; Val loss 0.1686062216758728
# Epoch 54; Train loss 0.16264766454696655; Val loss 0.16847161948680878
# Epoch 55; Train loss 0.16168056428432465; Val loss 0.16776098310947418
# Epoch 56; Train loss 0.16067302227020264; Val loss 0.16788899898529053
# Epoch 57; Train loss 0.1600065380334854; Val loss 0.16583943367004395
# Epoch 58; Train loss 0.15948091447353363; Val loss 0.16678200662136078
# Epoch 59; Train loss 0.15884637832641602; Val loss 0.16446363925933838
# Epoch 60; Train loss 0.15785709023475647; Val loss 0.16511134803295135
# Epoch 61; Train loss 0.15781784057617188; Val loss 0.16310080885887146
# Epoch 62; Train loss 0.15724022686481476; Val loss 0.1633724719285965
# Epoch 63; Train loss 0.15757787227630615; Val loss 0.16328920423984528
# Epoch 64; Train loss 0.1564083695411682; Val loss 0.16382461786270142
# Epoch 65; Train loss 0.15689200162887573; Val loss 0.16398173570632935
# Epoch 66; Train loss 0.15690505504608154; Val loss 0.16291871666908264
# Epoch 67; Train loss 0.15673264861106873; Val loss 0.16317249834537506
# Epoch 68; Train loss 0.15686768293380737; Val loss 0.16248448193073273
# Epoch 69; Train loss 0.1569821536540985; Val loss 0.16282829642295837
# Epoch 70; Train loss 0.15669159591197968; Val loss 0.16235825419425964
# Epoch 71; Train loss 0.15658675134181976; Val loss 0.16296903789043427
# Epoch 72; Train loss 0.1568099707365036; Val loss 0.1642879843711853
# Epoch 73; Train loss 0.1567022204399109; Val loss 0.16236525774002075
# Epoch 74; Train loss 0.15652595460414886; Val loss 0.1620333045721054
# Epoch 75; Train loss 0.15637171268463135; Val loss 0.16267043352127075
# Epoch 76; Train loss 0.15628519654273987; Val loss 0.16325272619724274
# Epoch 77; Train loss 0.156145378947258; Val loss 0.1630447953939438
# Epoch 78; Train loss 0.15627847611904144; Val loss 0.16267527639865875
# Epoch 79; Train loss 0.15620210766792297; Val loss 0.16268454492092133
# Epoch 80; Train loss 0.1562412977218628; Val loss 0.1630624532699585
# Epoch 81; Train loss 0.15671278536319733; Val loss 0.16242057085037231
# Epoch 82; Train loss 0.15646742284297943; Val loss 0.16412128508090973
# Epoch 83; Train loss 0.1565811187028885; Val loss 0.16229955852031708
# Epoch 84; Train loss 0.15657296776771545; Val loss 0.16313710808753967
# Epoch 85; Train loss 0.15607060492038727; Val loss 0.16226555407047272
# Epoch 86; Train loss 0.15575222671031952; Val loss 0.1610838919878006
# Epoch 87; Train loss 0.156250461935997; Val loss 0.16217948496341705
# Epoch 88; Train loss 0.15573453903198242; Val loss 0.1610879898071289
# Epoch 89; Train loss 0.15574097633361816; Val loss 0.16170082986354828
# Epoch 90; Train loss 0.15535035729408264; Val loss 0.16245901584625244
# Epoch 91; Train loss 0.15480129420757294; Val loss 0.16161151230335236
# Epoch 92; Train loss 0.15582095086574554; Val loss 0.16234317421913147
# Epoch 93; Train loss 0.15532781183719635; Val loss 0.16126534342765808
# Epoch 94; Train loss 0.1554955393075943; Val loss 0.16174238920211792
# Epoch 95; Train loss 0.15525372326374054; Val loss 0.16261692345142365
# Epoch 96; Train loss 0.15545885264873505; Val loss 0.16311340034008026
# Epoch 97; Train loss 0.15491540729999542; Val loss 0.1627889722585678
# Epoch 98; Train loss 0.15517958998680115; Val loss 0.1620202362537384
# Epoch 99; Train loss 0.15477585792541504; Val loss 0.1626439243555069
# Epoch 100; Train loss 0.15570837259292603; Val loss 0.16250112652778625
# Epoch 101; Train loss 0.15525002777576447; Val loss 0.16029797494411469
# Epoch 102; Train loss 0.15463678538799286; Val loss 0.1592089682817459
# Epoch 103; Train loss 0.15513306856155396; Val loss 0.16148929297924042
# Epoch 104; Train loss 0.15450893342494965; Val loss 0.1625327169895172
# Epoch 105; Train loss 0.1549471765756607; Val loss 0.16068316996097565
# Epoch 106; Train loss 0.15530520677566528; Val loss 0.16187968850135803
# Epoch 107; Train loss 0.15459974110126495; Val loss 0.1621292382478714
# Epoch 108; Train loss 0.15445299446582794; Val loss 0.1612747609615326
# Epoch 109; Train loss 0.15519100427627563; Val loss 0.16133779287338257
# Epoch 110; Train loss 0.15476053953170776; Val loss 0.16148480772972107
# Epoch 111; Train loss 0.15421980619430542; Val loss 0.16164667904376984
# Epoch 112; Train loss 0.15404954552650452; Val loss 0.16144973039627075
# Epoch 113; Train loss 0.15410460531711578; Val loss 0.1605193316936493
# Epoch 114; Train loss 0.15446248650550842; Val loss 0.15986968576908112
# Epoch 115; Train loss 0.15422523021697998; Val loss 0.16020236909389496
# Epoch 116; Train loss 0.15513767302036285; Val loss 0.16096113622188568
# Epoch 117; Train loss 0.15359827876091003; Val loss 0.15953373908996582
# Epoch 118; Train loss 0.15315037965774536; Val loss 0.15982604026794434
# Epoch 119; Train loss 0.15311264991760254; Val loss 0.16010215878486633
# Epoch 120; Train loss 0.1536417007446289; Val loss 0.15984302759170532
# Epoch 121; Train loss 0.1532430499792099; Val loss 0.15880760550498962
# Epoch 122; Train loss 0.1534152776002884; Val loss 0.15936988592147827
# Epoch 123; Train loss 0.15274639427661896; Val loss 0.1587856262922287
# Epoch 124; Train loss 0.15321151912212372; Val loss 0.15963749587535858
# Epoch 125; Train loss 0.1529042273759842; Val loss 0.15982913970947266
# Epoch 126; Train loss 0.15262392163276672; Val loss 0.16033953428268433
# Epoch 127; Train loss 0.15282301604747772; Val loss 0.16101372241973877
# Epoch 128; Train loss 0.15174424648284912; Val loss 0.15896718204021454
# Epoch 129; Train loss 0.15237164497375488; Val loss 0.15924812853336334
# Epoch 130; Train loss 0.15232661366462708; Val loss 0.15796104073524475
# Epoch 131; Train loss 0.15161268413066864; Val loss 0.1592073142528534
# Epoch 132; Train loss 0.15177881717681885; Val loss 0.15819351375102997
# Epoch 133; Train loss 0.15161825716495514; Val loss 0.15951478481292725
# Epoch 134; Train loss 0.1515025496482849; Val loss 0.15886804461479187
# Epoch 135; Train loss 0.1516953855752945; Val loss 0.15757645666599274
# Epoch 136; Train loss 0.15051338076591492; Val loss 0.15587306022644043
# Epoch 137; Train loss 0.15076464414596558; Val loss 0.15631674230098724
# Epoch 138; Train loss 0.15044599771499634; Val loss 0.15676814317703247
# Epoch 139; Train loss 0.15024368464946747; Val loss 0.15800555050373077
# Epoch 140; Train loss 0.1510729044675827; Val loss 0.1562802791595459
# Epoch 141; Train loss 0.1508522629737854; Val loss 0.1564355045557022
# Epoch 142; Train loss 0.1503434181213379; Val loss 0.15727172791957855
# Epoch 143; Train loss 0.14981135725975037; Val loss 0.15712158381938934
# Epoch 144; Train loss 0.1498737335205078; Val loss 0.15701337158679962
# Epoch 145; Train loss 0.1496150642633438; Val loss 0.1560230404138565
# Epoch 146; Train loss 0.14998993277549744; Val loss 0.15556064248085022
# Epoch 147; Train loss 0.14917954802513123; Val loss 0.15702205896377563
# Epoch 148; Train loss 0.1495351493358612; Val loss 0.15644124150276184
# Epoch 149; Train loss 0.14945587515830994; Val loss 0.15712621808052063
# Epoch 150; Train loss 0.14884981513023376; Val loss 0.15597261488437653
# Epoch 151; Train loss 0.14896158874034882; Val loss 0.15641827881336212
# Epoch 152; Train loss 0.14893297851085663; Val loss 0.15644335746765137
# Epoch 153; Train loss 0.1486753225326538; Val loss 0.15511389076709747
# Epoch 154; Train loss 0.1487424522638321; Val loss 0.15434886515140533
# Epoch 155; Train loss 0.14843757450580597; Val loss 0.15652230381965637
# Epoch 156; Train loss 0.14827316999435425; Val loss 0.15547557175159454
# Epoch 157; Train loss 0.1479053646326065; Val loss 0.1542454957962036
# Epoch 158; Train loss 0.1488363891839981; Val loss 0.15524891018867493
# Epoch 159; Train loss 0.14759710431098938; Val loss 0.1550585925579071
# Epoch 160; Train loss 0.14768509566783905; Val loss 0.15437312424182892
# Epoch 161; Train loss 0.1476309597492218; Val loss 0.15337231755256653
# Epoch 162; Train loss 0.1474177986383438; Val loss 0.15470324456691742
# Epoch 163; Train loss 0.14759966731071472; Val loss 0.15324516594409943
# Epoch 164; Train loss 0.14721167087554932; Val loss 0.15440532565116882
# Epoch 165; Train loss 0.1473669707775116; Val loss 0.15355782210826874
# Epoch 166; Train loss 0.14728353917598724; Val loss 0.1534869521856308
# Epoch 167; Train loss 0.14725954830646515; Val loss 0.15445473790168762
# Epoch 168; Train loss 0.1467796415090561; Val loss 0.15257108211517334
# Epoch 169; Train loss 0.14720138907432556; Val loss 0.1542036533355713
# Epoch 170; Train loss 0.14717435836791992; Val loss 0.15350677073001862
# Epoch 171; Train loss 0.1472025066614151; Val loss 0.15401317179203033
# Epoch 172; Train loss 0.1463979035615921; Val loss 0.1537328064441681
# Epoch 173; Train loss 0.14666631817817688; Val loss 0.15356744825839996
# Epoch 174; Train loss 0.14672750234603882; Val loss 0.1535322219133377
# Epoch 175; Train loss 0.14587707817554474; Val loss 0.152513787150383
# Epoch 176; Train loss 0.1460529863834381; Val loss 0.15326935052871704
# Epoch 177; Train loss 0.146552175283432; Val loss 0.15201722085475922
# Epoch 178; Train loss 0.14563460648059845; Val loss 0.15333782136440277
# Epoch 179; Train loss 0.14581134915351868; Val loss 0.15211345255374908
# Epoch 180; Train loss 0.1455376297235489; Val loss 0.15332575142383575
# Epoch 181; Train loss 0.14539681375026703; Val loss 0.15326939523220062
# Epoch 182; Train loss 0.1454562097787857; Val loss 0.15222179889678955
# Epoch 183; Train loss 0.14538811147212982; Val loss 0.1529199779033661
# Epoch 184; Train loss 0.145348459482193; Val loss 0.15122051537036896
# Epoch 185; Train loss 0.14527978003025055; Val loss 0.15215443074703217
# Epoch 186; Train loss 0.14535541832447052; Val loss 0.1518527865409851
# Epoch 187; Train loss 0.14532604813575745; Val loss 0.1529381424188614
# Epoch 188; Train loss 0.14544285833835602; Val loss 0.15261238813400269
# Epoch 189; Train loss 0.14541581273078918; Val loss 0.15205518901348114
# Epoch 190; Train loss 0.14480042457580566; Val loss 0.15124091506004333
# Epoch 191; Train loss 0.14563624560832977; Val loss 0.15171518921852112
# Epoch 192; Train loss 0.1452019363641739; Val loss 0.15214185416698456
# Epoch 193; Train loss 0.14471669495105743; Val loss 0.15183350443840027
# Epoch 194; Train loss 0.14591814577579498; Val loss 0.15171831846237183
# Epoch 195; Train loss 0.14539016783237457; Val loss 0.15054433047771454
# Epoch 196; Train loss 0.14511242508888245; Val loss 0.15194690227508545
# Epoch 197; Train loss 0.1451680213212967; Val loss 0.15241079032421112
# Epoch 198; Train loss 0.14517998695373535; Val loss 0.15116216242313385
# Epoch 199; Train loss 0.14541120827198029; Val loss 0.15155142545700073
# Epoch 200; Train loss 0.14473757147789001; Val loss 0.15140801668167114
# Epoch 201; Train loss 0.14448295533657074; Val loss 0.15266697108745575
# Epoch 202; Train loss 0.14536292850971222; Val loss 0.15132248401641846
# Epoch 203; Train loss 0.14484193921089172; Val loss 0.15136335790157318
# Epoch 204; Train loss 0.1446894407272339; Val loss 0.15191273391246796
# Epoch 205; Train loss 0.14486689865589142; Val loss 0.15179358422756195
# Epoch 206; Train loss 0.14456243813037872; Val loss 0.15204206109046936
# Epoch 207; Train loss 0.1444537192583084; Val loss 0.15178996324539185
# Epoch 208; Train loss 0.14498919248580933; Val loss 0.15131208300590515
# Epoch 209; Train loss 0.14447851479053497; Val loss 0.15227890014648438
# Epoch 210; Train loss 0.14488089084625244; Val loss 0.15123890340328217
# Epoch 211; Train loss 0.14415457844734192; Val loss 0.15115265548229218
# Epoch 212; Train loss 0.1444585919380188; Val loss 0.15019822120666504
# Epoch 213; Train loss 0.14508511126041412; Val loss 0.15071606636047363
# Epoch 214; Train loss 0.14396996796131134; Val loss 0.15066368877887726
# Epoch 215; Train loss 0.14438916742801666; Val loss 0.1514529138803482
# Epoch 216; Train loss 0.14400145411491394; Val loss 0.15285004675388336
# Epoch 217; Train loss 0.14419400691986084; Val loss 0.15091152489185333
# Epoch 218; Train loss 0.14413298666477203; Val loss 0.15178564190864563
# Epoch 219; Train loss 0.14454296231269836; Val loss 0.1513395607471466
# Epoch 220; Train loss 0.14444021880626678; Val loss 0.15031659603118896
# Epoch 221; Train loss 0.14374424517154694; Val loss 0.14998069405555725
# Epoch 222; Train loss 0.1444101184606552; Val loss 0.15081726014614105
# Epoch 223; Train loss 0.144453227519989; Val loss 0.15063510835170746
# Epoch 224; Train loss 0.14422255754470825; Val loss 0.15150748193264008
# Epoch 225; Train loss 0.14441357553005219; Val loss 0.15129153430461884
# Epoch 226; Train loss 0.14428158104419708; Val loss 0.15080678462982178
# Epoch 227; Train loss 0.14331647753715515; Val loss 0.15128584206104279
# Epoch 228; Train loss 0.144008606672287; Val loss 0.15135882794857025
# Epoch 229; Train loss 0.14372098445892334; Val loss 0.15064245462417603
# Epoch 230; Train loss 0.14358632266521454; Val loss 0.1522308886051178
# Epoch 231; Train loss 0.14365392923355103; Val loss 0.15082328021526337
# Epoch 232; Train loss 0.14408734440803528; Val loss 0.1508200317621231
# Epoch 233; Train loss 0.14404845237731934; Val loss 0.15048767626285553
# Epoch 234; Train loss 0.14348258078098297; Val loss 0.1502608060836792
# Epoch 235; Train loss 0.14342324435710907; Val loss 0.15201279520988464
# Epoch 236; Train loss 0.14357009530067444; Val loss 0.1510397344827652
# Epoch 237; Train loss 0.1437603086233139; Val loss 0.15168413519859314
# Epoch 238; Train loss 0.1434934437274933; Val loss 0.15102456510066986
# Epoch 239; Train loss 0.14370645582675934; Val loss 0.15021806955337524
# Epoch 240; Train loss 0.14324654638767242; Val loss 0.1506531834602356
# Epoch 241; Train loss 0.14344725012779236; Val loss 0.1498251110315323
# Epoch 242; Train loss 0.14333046972751617; Val loss 0.1485496312379837
# Epoch 243; Train loss 0.14346545934677124; Val loss 0.15070922672748566
# Epoch 244; Train loss 0.14402151107788086; Val loss 0.1505354344844818
# Epoch 245; Train loss 0.14367958903312683; Val loss 0.15130852162837982
# Epoch 246; Train loss 0.1434384435415268; Val loss 0.14967481791973114
# Epoch 247; Train loss 0.1430606245994568; Val loss 0.15157878398895264
# Epoch 248; Train loss 0.14379417896270752; Val loss 0.14984966814517975
# Epoch 249; Train loss 0.14311309158802032; Val loss 0.14914141595363617
# Epoch 250; Train loss 0.14347143471240997; Val loss 0.15044598281383514
# Epoch 251; Train loss 0.14298467338085175; Val loss 0.15114529430866241
# Epoch 252; Train loss 0.1430988609790802; Val loss 0.15023133158683777
# Epoch 253; Train loss 0.14368587732315063; Val loss 0.1505991816520691
# Epoch 254; Train loss 0.14338721334934235; Val loss 0.1504400670528412
# Epoch 255; Train loss 0.14321644604206085; Val loss 0.15076777338981628
# Epoch 256; Train loss 0.1432434618473053; Val loss 0.15066570043563843
# Epoch 257; Train loss 0.14286722242832184; Val loss 0.1505083590745926
# Epoch 258; Train loss 0.14349544048309326; Val loss 0.15053069591522217
# Epoch 259; Train loss 0.14350618422031403; Val loss 0.14959529042243958
# Epoch 260; Train loss 0.1433546096086502; Val loss 0.1515817791223526
# Epoch 261; Train loss 0.14352834224700928; Val loss 0.1508769392967224
# Epoch 262; Train loss 0.1434185653924942; Val loss 0.15088695287704468
# Epoch 263; Train loss 0.143014058470726; Val loss 0.1509806513786316
# Epoch 264; Train loss 0.14342790842056274; Val loss 0.1502148061990738
# Epoch 265; Train loss 0.14298704266548157; Val loss 0.1497604101896286
# Epoch 266; Train loss 0.14284475147724152; Val loss 0.15068764984607697
# Epoch 267; Train loss 0.14287684857845306; Val loss 0.15028399229049683
# Epoch 268; Train loss 0.14301797747612; Val loss 0.15127792954444885
# Epoch 269; Train loss 0.14294444024562836; Val loss 0.1488601714372635
# Epoch 270; Train loss 0.1427234262228012; Val loss 0.14959612488746643
# Epoch 271; Train loss 0.1434730440378189; Val loss 0.1499750018119812
# Epoch 272; Train loss 0.14329414069652557; Val loss 0.14962127804756165
# Epoch 273; Train loss 0.14290370047092438; Val loss 0.1502806544303894
# Epoch 274; Train loss 0.14270424842834473; Val loss 0.14937306940555573
# Epoch 275; Train loss 0.14261369407176971; Val loss 0.14906831085681915
# Epoch 276; Train loss 0.14313971996307373; Val loss 0.14988908171653748
# Epoch 277; Train loss 0.14308303594589233; Val loss 0.14969702064990997
# Epoch 278; Train loss 0.14303532242774963; Val loss 0.1494290679693222
# Epoch 279; Train loss 0.14280414581298828; Val loss 0.14963729679584503
# Epoch 280; Train loss 0.1424231231212616; Val loss 0.15110984444618225
# Epoch 281; Train loss 0.14288780093193054; Val loss 0.14969487488269806
# Epoch 282; Train loss 0.1432940810918808; Val loss 0.15102078020572662
# Epoch 283; Train loss 0.14289408922195435; Val loss 0.15036725997924805
# Epoch 284; Train loss 0.14271843433380127; Val loss 0.1494295597076416
# Epoch 285; Train loss 0.1429745852947235; Val loss 0.14951767027378082
# Epoch 286; Train loss 0.14266455173492432; Val loss 0.1503002643585205
# Epoch 287; Train loss 0.14304468035697937; Val loss 0.14903828501701355
# Epoch 288; Train loss 0.14318087697029114; Val loss 0.1500053107738495
# Epoch 289; Train loss 0.14345254004001617; Val loss 0.14971911907196045
# Epoch 290; Train loss 0.14284345507621765; Val loss 0.1489105224609375
# Epoch 291; Train loss 0.1427706629037857; Val loss 0.14986976981163025
# Epoch 292; Train loss 0.14310571551322937; Val loss 0.1513274908065796
# Epoch 293; Train loss 0.14364293217658997; Val loss 0.15020015835762024
# Epoch 294; Train loss 0.14295195043087006; Val loss 0.14992904663085938
# Epoch 295; Train loss 0.14329920709133148; Val loss 0.15050046145915985
# Epoch 296; Train loss 0.14249864220619202; Val loss 0.14927729964256287
# Epoch 297; Train loss 0.14345741271972656; Val loss 0.1494157314300537
# Epoch 298; Train loss 0.1428666114807129; Val loss 0.15025052428245544
# Epoch 299; Train loss 0.1425182819366455; Val loss 0.15128177404403687
# {'train': {'loss': [tensor(0.6931, grad_fn=<DivBackward0>),
#    tensor(0.6927, grad_fn=<DivBackward0>),
#    tensor(0.6866, grad_fn=<DivBackward0>),
#    tensor(0.6706, grad_fn=<DivBackward0>),
#    tensor(0.6423, grad_fn=<DivBackward0>),
#    tensor(0.6020, grad_fn=<DivBackward0>),
#    tensor(0.5513, grad_fn=<DivBackward0>),
#    tensor(0.4942, grad_fn=<DivBackward0>),
#    tensor(0.4356, grad_fn=<DivBackward0>),
#    tensor(0.3807, grad_fn=<DivBackward0>),
#    tensor(0.3339, grad_fn=<DivBackward0>),
#    tensor(0.2957, grad_fn=<DivBackward0>),
#    tensor(0.2684, grad_fn=<DivBackward0>),
#    tensor(0.2484, grad_fn=<DivBackward0>),
#    tensor(0.2341, grad_fn=<DivBackward0>),
#    tensor(0.2254, grad_fn=<DivBackward0>),
#    tensor(0.2190, grad_fn=<DivBackward0>),
#    tensor(0.2152, grad_fn=<DivBackward0>),
#    tensor(0.2116, grad_fn=<DivBackward0>),
#    tensor(0.2087, grad_fn=<DivBackward0>),
#    tensor(0.2060, grad_fn=<DivBackward0>),
#    tensor(0.2032, grad_fn=<DivBackward0>),
#    tensor(0.2016, grad_fn=<DivBackward0>),
#    tensor(0.1979, grad_fn=<DivBackward0>),
#    tensor(0.1977, grad_fn=<DivBackward0>),
#    tensor(0.1959, grad_fn=<DivBackward0>),
#    tensor(0.1941, grad_fn=<DivBackward0>),
#    tensor(0.1915, grad_fn=<DivBackward0>),
#    tensor(0.1919, grad_fn=<DivBackward0>),
#    tensor(0.1906, grad_fn=<DivBackward0>),
#    tensor(0.1897, grad_fn=<DivBackward0>),
#    tensor(0.1888, grad_fn=<DivBackward0>),
#    tensor(0.1886, grad_fn=<DivBackward0>),
#    tensor(0.1875, grad_fn=<DivBackward0>),
#    tensor(0.1874, grad_fn=<DivBackward0>),
#    tensor(0.1881, grad_fn=<DivBackward0>),
#    tensor(0.1866, grad_fn=<DivBackward0>),
#    tensor(0.1858, grad_fn=<DivBackward0>),
#    tensor(0.1852, grad_fn=<DivBackward0>),
#    tensor(0.1845, grad_fn=<DivBackward0>),
#    tensor(0.1830, grad_fn=<DivBackward0>),
#    tensor(0.1826, grad_fn=<DivBackward0>),
#    tensor(0.1806, grad_fn=<DivBackward0>),
#    tensor(0.1793, grad_fn=<DivBackward0>),
#    tensor(0.1780, grad_fn=<DivBackward0>),
#    tensor(0.1765, grad_fn=<DivBackward0>),
#    tensor(0.1749, grad_fn=<DivBackward0>),
#    tensor(0.1723, grad_fn=<DivBackward0>),
#    tensor(0.1711, grad_fn=<DivBackward0>),
#    tensor(0.1698, grad_fn=<DivBackward0>),
#    tensor(0.1676, grad_fn=<DivBackward0>),
#    tensor(0.1665, grad_fn=<DivBackward0>),
#    tensor(0.1651, grad_fn=<DivBackward0>),
#    tensor(0.1640, grad_fn=<DivBackward0>),
#    tensor(0.1626, grad_fn=<DivBackward0>),
#    tensor(0.1617, grad_fn=<DivBackward0>),
#    tensor(0.1607, grad_fn=<DivBackward0>),
#    tensor(0.1600, grad_fn=<DivBackward0>),
#    tensor(0.1595, grad_fn=<DivBackward0>),
#    tensor(0.1588, grad_fn=<DivBackward0>),
#    tensor(0.1579, grad_fn=<DivBackward0>),
#    tensor(0.1578, grad_fn=<DivBackward0>),
#    tensor(0.1572, grad_fn=<DivBackward0>),
#    tensor(0.1576, grad_fn=<DivBackward0>),
#    tensor(0.1564, grad_fn=<DivBackward0>),
#    tensor(0.1569, grad_fn=<DivBackward0>),
#    tensor(0.1569, grad_fn=<DivBackward0>),
#    tensor(0.1567, grad_fn=<DivBackward0>),
#    tensor(0.1569, grad_fn=<DivBackward0>),
#    tensor(0.1570, grad_fn=<DivBackward0>),
#    tensor(0.1567, grad_fn=<DivBackward0>),
#    tensor(0.1566, grad_fn=<DivBackward0>),
#    tensor(0.1568, grad_fn=<DivBackward0>),
#    tensor(0.1567, grad_fn=<DivBackward0>),
#    tensor(0.1565, grad_fn=<DivBackward0>),
#    tensor(0.1564, grad_fn=<DivBackward0>),
#    tensor(0.1563, grad_fn=<DivBackward0>),
#    tensor(0.1561, grad_fn=<DivBackward0>),
#    tensor(0.1563, grad_fn=<DivBackward0>),
#    tensor(0.1562, grad_fn=<DivBackward0>),
#    tensor(0.1562, grad_fn=<DivBackward0>),
#    tensor(0.1567, grad_fn=<DivBackward0>),
#    tensor(0.1565, grad_fn=<DivBackward0>),
#    tensor(0.1566, grad_fn=<DivBackward0>),
#    tensor(0.1566, grad_fn=<DivBackward0>),
#    tensor(0.1561, grad_fn=<DivBackward0>),
#    tensor(0.1558, grad_fn=<DivBackward0>),
#    tensor(0.1563, grad_fn=<DivBackward0>),
#    tensor(0.1557, grad_fn=<DivBackward0>),
#    tensor(0.1557, grad_fn=<DivBackward0>),
#    tensor(0.1554, grad_fn=<DivBackward0>),
#    tensor(0.1548, grad_fn=<DivBackward0>),
#    tensor(0.1558, grad_fn=<DivBackward0>),
#    tensor(0.1553, grad_fn=<DivBackward0>),
#    tensor(0.1555, grad_fn=<DivBackward0>),
#    tensor(0.1553, grad_fn=<DivBackward0>),
#    tensor(0.1555, grad_fn=<DivBackward0>),
#    tensor(0.1549, grad_fn=<DivBackward0>),
#    tensor(0.1552, grad_fn=<DivBackward0>),
#    tensor(0.1548, grad_fn=<DivBackward0>),
#    tensor(0.1557, grad_fn=<DivBackward0>),
#    tensor(0.1553, grad_fn=<DivBackward0>),
#    tensor(0.1546, grad_fn=<DivBackward0>),
#    tensor(0.1551, grad_fn=<DivBackward0>),
#    tensor(0.1545, grad_fn=<DivBackward0>),
#    tensor(0.1549, grad_fn=<DivBackward0>),
#    tensor(0.1553, grad_fn=<DivBackward0>),
#    tensor(0.1546, grad_fn=<DivBackward0>),
#    tensor(0.1545, grad_fn=<DivBackward0>),
#    tensor(0.1552, grad_fn=<DivBackward0>),
#    tensor(0.1548, grad_fn=<DivBackward0>),
#    tensor(0.1542, grad_fn=<DivBackward0>),
#    tensor(0.1540, grad_fn=<DivBackward0>),
#    tensor(0.1541, grad_fn=<DivBackward0>),
#    tensor(0.1545, grad_fn=<DivBackward0>),
#    tensor(0.1542, grad_fn=<DivBackward0>),
#    tensor(0.1551, grad_fn=<DivBackward0>),
#    tensor(0.1536, grad_fn=<DivBackward0>),
#    tensor(0.1532, grad_fn=<DivBackward0>),
#    tensor(0.1531, grad_fn=<DivBackward0>),
#    tensor(0.1536, grad_fn=<DivBackward0>),
#    tensor(0.1532, grad_fn=<DivBackward0>),
#    tensor(0.1534, grad_fn=<DivBackward0>),
#    tensor(0.1527, grad_fn=<DivBackward0>),
#    tensor(0.1532, grad_fn=<DivBackward0>),
#    tensor(0.1529, grad_fn=<DivBackward0>),
#    tensor(0.1526, grad_fn=<DivBackward0>),
#    tensor(0.1528, grad_fn=<DivBackward0>),
#    tensor(0.1517, grad_fn=<DivBackward0>),
#    tensor(0.1524, grad_fn=<DivBackward0>),
#    tensor(0.1523, grad_fn=<DivBackward0>),
#    tensor(0.1516, grad_fn=<DivBackward0>),
#    tensor(0.1518, grad_fn=<DivBackward0>),
#    tensor(0.1516, grad_fn=<DivBackward0>),
#    tensor(0.1515, grad_fn=<DivBackward0>),
#    tensor(0.1517, grad_fn=<DivBackward0>),
#    tensor(0.1505, grad_fn=<DivBackward0>),
#    tensor(0.1508, grad_fn=<DivBackward0>),
#    tensor(0.1504, grad_fn=<DivBackward0>),
#    tensor(0.1502, grad_fn=<DivBackward0>),
#    tensor(0.1511, grad_fn=<DivBackward0>),
#    tensor(0.1509, grad_fn=<DivBackward0>),
#    tensor(0.1503, grad_fn=<DivBackward0>),
#    tensor(0.1498, grad_fn=<DivBackward0>),
#    tensor(0.1499, grad_fn=<DivBackward0>),
#    tensor(0.1496, grad_fn=<DivBackward0>),
#    tensor(0.1500, grad_fn=<DivBackward0>),
#    tensor(0.1492, grad_fn=<DivBackward0>),
#    tensor(0.1495, grad_fn=<DivBackward0>),
#    tensor(0.1495, grad_fn=<DivBackward0>),
#    tensor(0.1488, grad_fn=<DivBackward0>),
#    tensor(0.1490, grad_fn=<DivBackward0>),
#    tensor(0.1489, grad_fn=<DivBackward0>),
#    tensor(0.1487, grad_fn=<DivBackward0>),
#    tensor(0.1487, grad_fn=<DivBackward0>),
#    tensor(0.1484, grad_fn=<DivBackward0>),
#    tensor(0.1483, grad_fn=<DivBackward0>),
#    tensor(0.1479, grad_fn=<DivBackward0>),
#    tensor(0.1488, grad_fn=<DivBackward0>),
#    tensor(0.1476, grad_fn=<DivBackward0>),
#    tensor(0.1477, grad_fn=<DivBackward0>),
#    tensor(0.1476, grad_fn=<DivBackward0>),
#    tensor(0.1474, grad_fn=<DivBackward0>),
#    tensor(0.1476, grad_fn=<DivBackward0>),
#    tensor(0.1472, grad_fn=<DivBackward0>),
#    tensor(0.1474, grad_fn=<DivBackward0>),
#    tensor(0.1473, grad_fn=<DivBackward0>),
#    tensor(0.1473, grad_fn=<DivBackward0>),
#    tensor(0.1468, grad_fn=<DivBackward0>),
#    tensor(0.1472, grad_fn=<DivBackward0>),
#    tensor(0.1472, grad_fn=<DivBackward0>),
#    tensor(0.1472, grad_fn=<DivBackward0>),
#    tensor(0.1464, grad_fn=<DivBackward0>),
#    tensor(0.1467, grad_fn=<DivBackward0>),
#    tensor(0.1467, grad_fn=<DivBackward0>),
#    tensor(0.1459, grad_fn=<DivBackward0>),
#    tensor(0.1461, grad_fn=<DivBackward0>),
#    tensor(0.1466, grad_fn=<DivBackward0>),
#    tensor(0.1456, grad_fn=<DivBackward0>),
#    tensor(0.1458, grad_fn=<DivBackward0>),
#    tensor(0.1455, grad_fn=<DivBackward0>),
#    tensor(0.1454, grad_fn=<DivBackward0>),
#    tensor(0.1455, grad_fn=<DivBackward0>),
#    tensor(0.1454, grad_fn=<DivBackward0>),
#    tensor(0.1453, grad_fn=<DivBackward0>),
#    tensor(0.1453, grad_fn=<DivBackward0>),
#    tensor(0.1454, grad_fn=<DivBackward0>),
#    tensor(0.1453, grad_fn=<DivBackward0>),
#    tensor(0.1454, grad_fn=<DivBackward0>),
#    tensor(0.1454, grad_fn=<DivBackward0>),
#    tensor(0.1448, grad_fn=<DivBackward0>),
#    tensor(0.1456, grad_fn=<DivBackward0>),
#    tensor(0.1452, grad_fn=<DivBackward0>),
#    tensor(0.1447, grad_fn=<DivBackward0>),
#    tensor(0.1459, grad_fn=<DivBackward0>),
#    tensor(0.1454, grad_fn=<DivBackward0>),
#    tensor(0.1451, grad_fn=<DivBackward0>),
#    tensor(0.1452, grad_fn=<DivBackward0>),
#    tensor(0.1452, grad_fn=<DivBackward0>),
#    tensor(0.1454, grad_fn=<DivBackward0>),
#    tensor(0.1447, grad_fn=<DivBackward0>),
#    tensor(0.1445, grad_fn=<DivBackward0>),
#    tensor(0.1454, grad_fn=<DivBackward0>),
#    tensor(0.1448, grad_fn=<DivBackward0>),
#    tensor(0.1447, grad_fn=<DivBackward0>),
#    tensor(0.1449, grad_fn=<DivBackward0>),
#    tensor(0.1446, grad_fn=<DivBackward0>),
#    tensor(0.1445, grad_fn=<DivBackward0>),
#    tensor(0.1450, grad_fn=<DivBackward0>),
#    tensor(0.1445, grad_fn=<DivBackward0>),
#    tensor(0.1449, grad_fn=<DivBackward0>),
#    tensor(0.1442, grad_fn=<DivBackward0>),
#    tensor(0.1445, grad_fn=<DivBackward0>),
#    tensor(0.1451, grad_fn=<DivBackward0>),
#    tensor(0.1440, grad_fn=<DivBackward0>),
#    tensor(0.1444, grad_fn=<DivBackward0>),
#    tensor(0.1440, grad_fn=<DivBackward0>),
#    tensor(0.1442, grad_fn=<DivBackward0>),
#    tensor(0.1441, grad_fn=<DivBackward0>),
#    tensor(0.1445, grad_fn=<DivBackward0>),
#    tensor(0.1444, grad_fn=<DivBackward0>),
#    tensor(0.1437, grad_fn=<DivBackward0>),
#    tensor(0.1444, grad_fn=<DivBackward0>),
#    tensor(0.1445, grad_fn=<DivBackward0>),
#    tensor(0.1442, grad_fn=<DivBackward0>),
#    tensor(0.1444, grad_fn=<DivBackward0>),
#    tensor(0.1443, grad_fn=<DivBackward0>),
#    tensor(0.1433, grad_fn=<DivBackward0>),
#    tensor(0.1440, grad_fn=<DivBackward0>),
#    tensor(0.1437, grad_fn=<DivBackward0>),
#    tensor(0.1436, grad_fn=<DivBackward0>),
#    tensor(0.1437, grad_fn=<DivBackward0>),
#    tensor(0.1441, grad_fn=<DivBackward0>),
#    tensor(0.1440, grad_fn=<DivBackward0>),
#    tensor(0.1435, grad_fn=<DivBackward0>),
#    tensor(0.1434, grad_fn=<DivBackward0>),
#    tensor(0.1436, grad_fn=<DivBackward0>),
#    tensor(0.1438, grad_fn=<DivBackward0>),
#    tensor(0.1435, grad_fn=<DivBackward0>),
#    tensor(0.1437, grad_fn=<DivBackward0>),
#    tensor(0.1432, grad_fn=<DivBackward0>),
#    tensor(0.1434, grad_fn=<DivBackward0>),
#    tensor(0.1433, grad_fn=<DivBackward0>),
#    tensor(0.1435, grad_fn=<DivBackward0>),
#    tensor(0.1440, grad_fn=<DivBackward0>),
#    tensor(0.1437, grad_fn=<DivBackward0>),
#    tensor(0.1434, grad_fn=<DivBackward0>),
#    tensor(0.1431, grad_fn=<DivBackward0>),
#    tensor(0.1438, grad_fn=<DivBackward0>),
#    tensor(0.1431, grad_fn=<DivBackward0>),
#    tensor(0.1435, grad_fn=<DivBackward0>),
#    tensor(0.1430, grad_fn=<DivBackward0>),
#    tensor(0.1431, grad_fn=<DivBackward0>),
#    tensor(0.1437, grad_fn=<DivBackward0>),
#    tensor(0.1434, grad_fn=<DivBackward0>),
#    tensor(0.1432, grad_fn=<DivBackward0>),
#    tensor(0.1432, grad_fn=<DivBackward0>),
#    tensor(0.1429, grad_fn=<DivBackward0>),
#    tensor(0.1435, grad_fn=<DivBackward0>),
#    tensor(0.1435, grad_fn=<DivBackward0>),
#    tensor(0.1434, grad_fn=<DivBackward0>),
#    tensor(0.1435, grad_fn=<DivBackward0>),
#    tensor(0.1434, grad_fn=<DivBackward0>),
#    tensor(0.1430, grad_fn=<DivBackward0>),
#    tensor(0.1434, grad_fn=<DivBackward0>),
#    tensor(0.1430, grad_fn=<DivBackward0>),
#    tensor(0.1428, grad_fn=<DivBackward0>),
#    tensor(0.1429, grad_fn=<DivBackward0>),
#    tensor(0.1430, grad_fn=<DivBackward0>),
#    tensor(0.1429, grad_fn=<DivBackward0>),
#    tensor(0.1427, grad_fn=<DivBackward0>),
#    tensor(0.1435, grad_fn=<DivBackward0>),
#    tensor(0.1433, grad_fn=<DivBackward0>),
#    tensor(0.1429, grad_fn=<DivBackward0>),
#    tensor(0.1427, grad_fn=<DivBackward0>),
#    tensor(0.1426, grad_fn=<DivBackward0>),
#    tensor(0.1431, grad_fn=<DivBackward0>),
#    tensor(0.1431, grad_fn=<DivBackward0>),
#    tensor(0.1430, grad_fn=<DivBackward0>),
#    tensor(0.1428, grad_fn=<DivBackward0>),
#    tensor(0.1424, grad_fn=<DivBackward0>),
#    tensor(0.1429, grad_fn=<DivBackward0>),
#    tensor(0.1433, grad_fn=<DivBackward0>),
#    tensor(0.1429, grad_fn=<DivBackward0>),
#    tensor(0.1427, grad_fn=<DivBackward0>),
#    tensor(0.1430, grad_fn=<DivBackward0>),
#    tensor(0.1427, grad_fn=<DivBackward0>),
#    tensor(0.1430, grad_fn=<DivBackward0>),
#    tensor(0.1432, grad_fn=<DivBackward0>),
#    tensor(0.1435, grad_fn=<DivBackward0>),
#    tensor(0.1428, grad_fn=<DivBackward0>),
#    tensor(0.1428, grad_fn=<DivBackward0>),
#    tensor(0.1431, grad_fn=<DivBackward0>),
#    tensor(0.1436, grad_fn=<DivBackward0>),
#    tensor(0.1430, grad_fn=<DivBackward0>),
#    tensor(0.1433, grad_fn=<DivBackward0>),
#    tensor(0.1425, grad_fn=<DivBackward0>),
#    tensor(0.1435, grad_fn=<DivBackward0>),
#    tensor(0.1429, grad_fn=<DivBackward0>),
#    tensor(0.1425, grad_fn=<DivBackward0>)]},
#  'val': {'loss': [tensor(0.6928),
#    tensor(0.6868),
#    tensor(0.6709),
#    tensor(0.6429),
#    tensor(0.6027),
#    tensor(0.5526),
#    tensor(0.4957),
#    tensor(0.4374),
#    tensor(0.3832),
#    tensor(0.3367),
#    tensor(0.2998),
#    tensor(0.2739),
#    tensor(0.2549),
#    tensor(0.2411),
#    tensor(0.2325),
#    tensor(0.2272),
#    tensor(0.2216),
#    tensor(0.2188),
#    tensor(0.2169),
#    tensor(0.2112),
#    tensor(0.2146),
#    tensor(0.2081),
#    tensor(0.2064),
#    tensor(0.2046),
#    tensor(0.2028),
#    tensor(0.1998),
#    tensor(0.2015),
#    tensor(0.1988),
#    tensor(0.1996),
#    tensor(0.1978),
#    tensor(0.1941),
#    tensor(0.1942),
#    tensor(0.1907),
#    tensor(0.1924),
#    tensor(0.1912),
#    tensor(0.1911),
#    tensor(0.1913),
#    tensor(0.1897),
#    tensor(0.1905),
#    tensor(0.1881),
#    tensor(0.1888),
#    tensor(0.1871),
#    tensor(0.1863),
#    tensor(0.1837),
#    tensor(0.1825),
#    tensor(0.1800),
#    tensor(0.1784),
#    tensor(0.1756),
#    tensor(0.1751),
#    tensor(0.1723),
#    tensor(0.1730),
#    tensor(0.1715),
#    tensor(0.1702),
#    tensor(0.1686),
#    tensor(0.1685),
#    tensor(0.1678),
#    tensor(0.1679),
#    tensor(0.1658),
#    tensor(0.1668),
#    tensor(0.1645),
#    tensor(0.1651),
#    tensor(0.1631),
#    tensor(0.1634),
#    tensor(0.1633),
#    tensor(0.1638),
#    tensor(0.1640),
#    tensor(0.1629),
#    tensor(0.1632),
#    tensor(0.1625),
#    tensor(0.1628),
#    tensor(0.1624),
#    tensor(0.1630),
#    tensor(0.1643),
#    tensor(0.1624),
#    tensor(0.1620),
#    tensor(0.1627),
#    tensor(0.1633),
#    tensor(0.1630),
#    tensor(0.1627),
#    tensor(0.1627),
#    tensor(0.1631),
#    tensor(0.1624),
#    tensor(0.1641),
#    tensor(0.1623),
#    tensor(0.1631),
#    tensor(0.1623),
#    tensor(0.1611),
#    tensor(0.1622),
#    tensor(0.1611),
#    tensor(0.1617),
#    tensor(0.1625),
#    tensor(0.1616),
#    tensor(0.1623),
#    tensor(0.1613),
#    tensor(0.1617),
#    tensor(0.1626),
#    tensor(0.1631),
#    tensor(0.1628),
#    tensor(0.1620),
#    tensor(0.1626),
#    tensor(0.1625),
#    tensor(0.1603),
#    tensor(0.1592),
#    tensor(0.1615),
#    tensor(0.1625),
#    tensor(0.1607),
#    tensor(0.1619),
#    tensor(0.1621),
#    tensor(0.1613),
#    tensor(0.1613),
#    tensor(0.1615),
#    tensor(0.1616),
#    tensor(0.1614),
#    tensor(0.1605),
#    tensor(0.1599),
#    tensor(0.1602),
#    tensor(0.1610),
#    tensor(0.1595),
#    tensor(0.1598),
#    tensor(0.1601),
#    tensor(0.1598),
#    tensor(0.1588),
#    tensor(0.1594),
#    tensor(0.1588),
#    tensor(0.1596),
#    tensor(0.1598),
#    tensor(0.1603),
#    tensor(0.1610),
#    tensor(0.1590),
#    tensor(0.1592),
#    tensor(0.1580),
#    tensor(0.1592),
#    tensor(0.1582),
#    tensor(0.1595),
#    tensor(0.1589),
#    tensor(0.1576),
#    tensor(0.1559),
#    tensor(0.1563),
#    tensor(0.1568),
#    tensor(0.1580),
#    tensor(0.1563),
#    tensor(0.1564),
#    tensor(0.1573),
#    tensor(0.1571),
#    tensor(0.1570),
#    tensor(0.1560),
#    tensor(0.1556),
#    tensor(0.1570),
#    tensor(0.1564),
#    tensor(0.1571),
#    tensor(0.1560),
#    tensor(0.1564),
#    tensor(0.1564),
#    tensor(0.1551),
#    tensor(0.1543),
#    tensor(0.1565),
#    tensor(0.1555),
#    tensor(0.1542),
#    tensor(0.1552),
#    tensor(0.1551),
#    tensor(0.1544),
#    tensor(0.1534),
#    tensor(0.1547),
#    tensor(0.1532),
#    tensor(0.1544),
#    tensor(0.1536),
#    tensor(0.1535),
#    tensor(0.1545),
#    tensor(0.1526),
#    tensor(0.1542),
#    tensor(0.1535),
#    tensor(0.1540),
#    tensor(0.1537),
#    tensor(0.1536),
#    tensor(0.1535),
#    tensor(0.1525),
#    tensor(0.1533),
#    tensor(0.1520),
#    tensor(0.1533),
#    tensor(0.1521),
#    tensor(0.1533),
#    tensor(0.1533),
#    tensor(0.1522),
#    tensor(0.1529),
#    tensor(0.1512),
#    tensor(0.1522),
#    tensor(0.1519),
#    tensor(0.1529),
#    tensor(0.1526),
#    tensor(0.1521),
#    tensor(0.1512),
#    tensor(0.1517),
#    tensor(0.1521),
#    tensor(0.1518),
#    tensor(0.1517),
#    tensor(0.1505),
#    tensor(0.1519),
#    tensor(0.1524),
#    tensor(0.1512),
#    tensor(0.1516),
#    tensor(0.1514),
#    tensor(0.1527),
#    tensor(0.1513),
#    tensor(0.1514),
#    tensor(0.1519),
#    tensor(0.1518),
#    tensor(0.1520),
#    tensor(0.1518),
#    tensor(0.1513),
#    tensor(0.1523),
#    tensor(0.1512),
#    tensor(0.1512),
#    tensor(0.1502),
#    tensor(0.1507),
#    tensor(0.1507),
#    tensor(0.1515),
#    tensor(0.1529),
#    tensor(0.1509),
#    tensor(0.1518),
#    tensor(0.1513),
#    tensor(0.1503),
#    tensor(0.1500),
#    tensor(0.1508),
#    tensor(0.1506),
#    tensor(0.1515),
#    tensor(0.1513),
#    tensor(0.1508),
#    tensor(0.1513),
#    tensor(0.1514),
#    tensor(0.1506),
#    tensor(0.1522),
#    tensor(0.1508),
#    tensor(0.1508),
#    tensor(0.1505),
#    tensor(0.1503),
#    tensor(0.1520),
#    tensor(0.1510),
#    tensor(0.1517),
#    tensor(0.1510),
#    tensor(0.1502),
#    tensor(0.1507),
#    tensor(0.1498),
#    tensor(0.1485),
#    tensor(0.1507),
#    tensor(0.1505),
#    tensor(0.1513),
#    tensor(0.1497),
#    tensor(0.1516),
#    tensor(0.1498),
#    tensor(0.1491),
#    tensor(0.1504),
#    tensor(0.1511),
#    tensor(0.1502),
#    tensor(0.1506),
#    tensor(0.1504),
#    tensor(0.1508),
#    tensor(0.1507),
#    tensor(0.1505),
#    tensor(0.1505),
#    tensor(0.1496),
#    tensor(0.1516),
#    tensor(0.1509),
#    tensor(0.1509),
#    tensor(0.1510),
#    tensor(0.1502),
#    tensor(0.1498),
#    tensor(0.1507),
#    tensor(0.1503),
#    tensor(0.1513),
#    tensor(0.1489),
#    tensor(0.1496),
#    tensor(0.1500),
#    tensor(0.1496),
#    tensor(0.1503),
#    tensor(0.1494),
#    tensor(0.1491),
#    tensor(0.1499),
#    tensor(0.1497),
#    tensor(0.1494),
#    tensor(0.1496),
#    tensor(0.1511),
#    tensor(0.1497),
#    tensor(0.1510),
#    tensor(0.1504),
#    tensor(0.1494),
#    tensor(0.1495),
#    tensor(0.1503),
#    tensor(0.1490),
#    tensor(0.1500),
#    tensor(0.1497),
#    tensor(0.1489),
#    tensor(0.1499),
#    tensor(0.1513),
#    tensor(0.1502),
#    tensor(0.1499),
#    tensor(0.1505),
#    tensor(0.1493),
#    tensor(0.1494),
#    tensor(0.1503),
#    tensor(0.1513)]}}

# %% [markdown]
# #### Generating Predictions for My User

# %%
# get my user ID as it pertains to nodes in the graph
my_user_id = node2id["user_200952"]
my_user_obj = None
for obj in users:
    if obj.name == "user_200952":
        my_user_obj = obj
        break

# %%
def get_subgraph_for_user(graph, user_id):
    # get all the edges associated with this user id
    graph_nx = to_networkx(test_split)
    user_edges = graph_nx.edges(user_id)
    # create a subgraph out of the edges that we just extracted
    user_subgraph = graph_nx.edge_subgraph(user_edges)
    return user_subgraph

user_subgraph = get_subgraph_for_user(test_split, my_user_id)
user_edge_idx = torch.Tensor(np.array(user_subgraph.edges()).T).type(torch.int64)
user_edge_idx
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x126244220>
# Traceback (most recent call last):
#   File "/Users/mariavmihu/Documents/MSCI 720/Final_Project/project-env/lib/python3.11/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/mariavmihu/Documents/MSCI 720/Final_Project/project-env/lib/python3.11/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
#     ^^^^^^^^^
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
# tensor([[16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857,
#          16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857,
#          16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857,
#          16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857, 16857,
#          16857, 16857, 16857, 16857],
#         [ 1630,  4022,  3394,  6602,  6256,  1197,   135,  1201,  7605,  2758,
#           1806,  2499,   480,  2854,  1786,  7247,  5666,  2663,  4355,   255,
#             87,  3592,  6601,   330,  5698,  1127,   416,  1749,   295,  3000,
#           6057,  1165,  6344,  7620,   101,  6891,  6255,  5191,  5763,  3379,
#           1844,  2921,  1299,  1612]])

# %%
movies_for_validation = user_edge_idx[1].tolist()
movies_for_validation = [id2node[m] for m in movies_for_validation]

filename = "results/my_user.qrels"
sorted_movies = sorted(movies_for_validation, key=lambda m: my_user_obj.ratings[m], reverse=True)
with open(filename, 'w', newline='') as results_file:
    for m in sorted_movies:
        user = 200952
        movieID = m.split("movie_")[1]
        score = my_user_obj.ratings[m]

        results_file.write(f"{user} 0 {movieID} {score}\n")

# %%
# get the embedding of all users and items using the model we just trained
embeddings = model.get_embedding(graph_data.edge_index) #should be the full dataset
embeddings.shape
# Out:
# torch.Size([24166, 64])

# %%
movie_embeddings = embeddings[:n_movies]
movie_embeddings.shape
# Out:
# torch.Size([7666, 64])

# %%
user_embeddings = embeddings[my_user_id]
user_embeddings = torch.unsqueeze(user_embeddings, 0)
user_embeddings.shape
# Out:
# torch.Size([1, 64])

# %%
predicted_ratings = torch.sigmoid(torch.matmul(user_embeddings, movie_embeddings.t()))
predicted_ratings.shape
# Out:
# torch.Size([1, 7666])

# %%
# this was taken from https://medium.com/stanford-cs224w/lightgcn-for-movie-recommendation-eb6d112f1e8
scores, top_movie_indices = torch.sort(predicted_ratings, descending=True)
movie_indices = top_movie_indices.squeeze().tolist()
scores = scores.squeeze().tolist()

# %%
k = 50
top_recommended_movies = movie_indices[:k]

# %%
# the movie IDs that are returned are the IDs as they appear in the graph, which means I need to do a bit of post-processing:
# 1. get the actual movielens IDs using node2id
# 2. get the name of the movie from movies_df
# 3. display the recs

print(f"Recommended for my user:")
for i, movie in enumerate(top_recommended_movies):
    movielensID = id2node[movie]
    movielensID = movielensID.split("movie_")[1]
    movie = movies_df[movies_df['movieId'] == int(movielensID)].iloc[0]
    movie_name = movie['title']
    movie_year = movie['year']
    print(f"{i+1}. {movie_name} ({movie_year})")
# Out:
# Recommended for my user:
# 1. Matrix, The  (1999)
# 2. Inception  (2010)
# 3. Fight Club  (1999)
# 4. Dark Knight, The  (2008)
# 5. Lord of the Rings: The Fellowship of the Ring, The  (2001)
# 6. Lord of the Rings: The Two Towers, The  (2002)
# 7. Lord of the Rings: The Return of the King, The  (2003)
# 8. Shawshank Redemption, The  (1994)
# 9. Pulp Fiction  (1994)
# 10. Shrek  (2001)
# 11. Star Wars: Episode IV - A New Hope  (1977)
# 12. Gladiator  (2000)
# 13. WALL·E  (2008)
# 14. Pirates of the Caribbean: The Curse of the Black Pearl  (2003)
# 15. Memento  (2000)
# 16. Silence of the Lambs, The  (1991)
# 17. Eternal Sunshine of the Spotless Mind  (2004)
# 18. Interstellar  (2014)
# 19. Monsters, Inc.  (2001)
# 20. Star Wars: Episode V - The Empire Strikes Back  (1980)
# 21. Raiders of the Lost Ark  (1981)
# 22. American Beauty  (1999)
# 23. Kill Bill: Vol. 1  (2003)
# 24. Up  (2009)
# 25. Finding Nemo  (2003)
# 26. Godfather, The  (1972)
# 27. Star Wars: Episode VI - Return of the Jedi  (1983)
# 28. Django Unchained  (2012)
# 29. Incredibles, The  (2004)
# 30. Schindler's List  (1993)
# 31. Iron Man  (2008)
# 32. Sixth Sense, The  (1999)
# 33. Usual Suspects, The  (1995)
# 34. Back to the Future  (1985)
# 35. Beautiful Mind, A  (2001)
# 36. V for Vendetta  (2006)
# 37. Avatar  (2009)
# 38. Amelie  (2001)
# 39. Bourne Identity, The  (2002)
# 40. Departed, The  (2006)
# 41. The Martian  (2015)
# 42. Seven  (1995)
# 43. Batman Begins  (2005)
# 44. Green Mile, The  (1999)
# 45. Kill Bill: Vol. 2  (2004)
# 46. X-Men  (2000)
# 47. American History X  (1998)
# 48. Truman Show, The  (1998)
# 49. Dark Knight Rises, The  (2012)
# 50. The Imitation Game  (2014)

# %% [markdown]
# #### Evaluation Metrics on My User

# %%
def write_qrels_to_file(file_name, scores, movies, userID, run):
    results = []
    with open( file_name, 'w', newline='' ) as results_file:
        for i, (score, movie) in enumerate(zip(scores, movies)):
            user_recs = {}
            user_recs['user'] = userID
            user_recs['Q0'] = 'Q0'
            user_recs['item'] = movie
            user_recs['rank'] = i
            user_recs['score'] = score
            user_recs['algorithm'] = run
            results.append(user_recs)
        
        writer = csv.DictWriter(results_file, fieldnames=['user', 'Q0', 'item', 'rank','score','algorithm'])
        writer.writerows(results)

# %%
# create directory to save model_stats
if not os.path.exists("results"):
  os.makedirs("results")

NAME_OF_RUN = "20k_explicit_nodes"
results_file_name = os.path.join("results", f"{NAME_OF_RUN}.csv")
write_qrels_to_file(results_file_name, scores, movie_indices, 200952, NAME_OF_RUN)

# %%
'''
    Code for NDCG
    citing my previous work in MSCI541 and MSCI720 assignment 3 for the overall logic in this snippet
'''
def compute_NDCG(k: int, qrels: dict, results: dict, metrics: dict, algo_name: str, NUM_USERS: int = 1011):

    NDCGs = []
    for_avg = 0

    # compute average precision
    for userid, recommendations in results.items():
        curr_dcg = 0
        curr_idcg = 0

        k_actual = min(k, len(recommendations))
        # compute DCG
        for i in range(k_actual):
            movie = recommendations[i]
            gain = 0 if movie not in qrels[userid].keys() else qrels[userid][movie]
            
            rank = i + 1
            curr_dcg += gain / (math.log2(1+rank))

        # figure out ideal search rankings
        #   1. get number of documents that are relevant
        rel_bar = len(qrels[userid].values())
        #   2. mimic ideal search results
        k_ideal = min(k, rel_bar)

        rank = 1
        for ground_truth_rating in qrels[userid].values():
            curr_idcg += ground_truth_rating / (math.log2(1+rank))
            rank += 1
            if rank > k_ideal:
                break

        # compute NDCG = DCG / IDCG
        curr_NCDG = curr_dcg / curr_idcg
        NDCGs.append(f"{userid},{curr_NCDG}")

        for_avg += curr_NCDG

    avg_NDCG = for_avg/NUM_USERS
    metric_name = f"NDCG_at_{k}"
    metrics[metric_name][algo_name] = avg_NDCG
    print(f"avg NDCG@{k}: {'{:.3f}'.format(round(avg_NDCG,6))}")
    return NDCGs

# %%
def get_qrels(qrels_path: str) -> dict:
    '''utility reading in QRELS file and saving it as a dictionary'''

    qrels_all_users = {}

    with open(qrels_path, 'r') as f:
        for line in f:
            parts_of_line = line.split()  

            userid, movie, rating = parts_of_line[0], parts_of_line[2], parts_of_line[3]
            if userid not in qrels_all_users.keys():
                qrels_all_users[userid] = {}
            
            qrels_all_users[userid][movie] = float(rating)

    return qrels_all_users

# %%
def get_results(results_path: str) -> tuple[dict, str]:
    '''
        Utility for reading in RESULTS file and saving it as a dictionary.
        The format of the dictionary is userid: [movieid, movieid, movieid].
            The results files are all sorted in order of rankings, so appending the movie IDs to a list should preserve the order for purposes of judging rank later.
    '''

    results_all_users = {}

    with open(results_path, 'r') as f:
        for line in f:
            parts_of_line = line.split(",")

            userid, movie, score = parts_of_line[0], parts_of_line[2], parts_of_line[3]
            algorithm = parts_of_line[5]
            if userid not in results_all_users.keys():
                results_all_users[userid] = []

            results_all_users[userid].append(movie)

    return results_all_users, algorithm

# %%
qrels_for_me = get_qrels(qrels_path="results/my_user.qrels")
qrels_for_me
# Out:
# {'200952': {'88163': 1.0,
#   '356': 1.0,
#   '60397': 1.0,
#   '2953': 1.0,
#   '40629': 0.9,
#   '4447': 0.9,
#   '109487': 0.9,
#   '111': 0.9,
#   '33493': 0.9,
#   '33615': 0.8,
#   '5995': 0.8,
#   '116797': 0.8,
#   '66203': 0.8,
#   '164909': 0.8,
#   '97921': 0.8,
#   '80166': 0.8,
#   '541': 0.8,
#   '6155': 0.8,
#   '286897': 0.8,
#   '7361': 0.7,
#   '6942': 0.7,
#   '275243': 0.7,
#   '260': 0.7,
#   '2797': 0.7,
#   '102903': 0.7,
#   '112552': 0.7,
#   '2': 0.7,
#   '69406': 0.7,
#   '204698': 0.7,
#   '104211': 0.6,
#   '1196': 0.6,
#   '201646': 0.6,
#   '2694': 0.6,
#   '70293': 0.6,
#   '1721': 0.6,
#   '202439': 0.5,
#   '193942': 0.4,
#   '166528': 0.4,
#   '166635': 0.4,
#   '162590': 0.4,
#   '192803': 0.4,
#   '97188': 0.1,
#   '7360': 0.1,
#   '103249': 0.1}}

# %%
results, name_of_algo = get_results(results_path=results_file_name)

metrics = {
    "NDCG_at_10": {},
    "NDCG_at_100": {},
    "NDCG_at_1000": {},
    f"NDCG_at_{n_movies}": {},
}

# compute NDCG @ 10 for me
NDCGs_at_10 = compute_NDCG(k=10, qrels=qrels_for_me, results=results, metrics=metrics, algo_name=name_of_algo, NUM_USERS=1)
# compute NDCG @ 100 for me
NDCGs_at_100 = compute_NDCG(k=100, qrels=qrels_for_me, results=results, metrics=metrics, algo_name=name_of_algo, NUM_USERS=1)
# compute NDCG @ 1000 for me
NDCGs_at_1000 = compute_NDCG(k=1000, qrels=qrels_for_me, results=results, metrics=metrics, algo_name=name_of_algo, NUM_USERS=1)
# compute NDCG @ 7840 for me
NDCGs_at_n_movies = compute_NDCG(k=n_movies, qrels=qrels_for_me, results=results, metrics=metrics, algo_name=name_of_algo, NUM_USERS=1)
# Out:
# avg NDCG@10: 0.000
# avg NDCG@100: 0.000
# avg NDCG@1000: 0.012
# avg NDCG@7666: 0.118
